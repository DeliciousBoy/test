# %%
from cleaner import *
from data import *

df = pd.read_excel('scg_products.xlsx')

df.rename(columns={'รูปสินค้า': 'image', 'ชื่อสินค้า': 'name', 'รหัสสินค้า': 'id',
                   'ขนาด': 'size', 'น้ำหนัก': 'weight', 'รุ่นสินค้า': 'model',
                   'ราคา': 'price', 'หน่วย': 'unit', 'โปรโมชั่น': 'promotion',
                   'ข้อมูลสินค้า': 'detail', 'คู่มือสินค้า': 'manual', 'ลิงค์คู่มือสินค้า': 'manual_link'}, inplace=True)

df['model'] = df['name'].apply(lambda x: 'อื่นๆ ' if not any(word in x for word in PRODUCT_MODEL) else next((word for word in PRODUCT_MODEL if word in x), 'อื่นๆ '))

a = ['สะท้อนความงดงามอย่างไทย อนุรักษ์สถาปัตยกรรมไทยอย่างมีนวัตกรรม\n- ผลิตจากวัตถุดิบคุณภาพ ทั้งผงดินและสีเคลือบสูตรพิเศษ ผ่านกระบวนการผลิตที่ทันสมัย มีระบบการควบคุมคุณภาพอย่างพิถีพิถันทุกขั้นตอนการผลิต ตลอดจนการตรวจสอบคุณภาพสินค้า กระเบื้องหลังคาเซรามิคเอ็กซ์เซลล่าจึงเป็นกระเบื้องหลังคาที่ได้มาตรฐาน\n- พร้อมทั้งผ่านการเคลือบสีและเผาที่อุณหภูมิสูงถึง 1,100 องศาเซลเซียส สีเคลือบจึงหลอมเป็นเนื้อเดียวกับกระเบื้อง แตกต่างจากวัสดุอื่นที่ไม่ผ่านการเผาที่อุณหภูมิสูง สีของกระเบื้องหลังคาเซรามิคเอ็กซ์เซลล่าจึงสวยงามข้ามกาลเวลา\n- วัตถุดิบจากเซรามิค จึงทำให้กระเบื้องหลังคามีผิวสัมผัสที่เรียบเนียน ดูโดดเด่นอย่างมีเอกลักษณ์\n- เทคโนโลยีการผลิตแบบ ผลิตด้วยระบบ Dry Press Fast Firing เป็นการขึ้นรูประบบแห้ง และเผาที่อุณหภูมิความร้อนสูงถึง 1,100 องศาเซลเซียส ทำให้ระดับความชื้นในตัวสินค้าต่ำ จึงทำให้เผาขึ้นรูปได้มาตรฐาน ไม่เกิดการบิดตัวของสินค้า\n- รูปแบบการเผาโดยผ่านสายพาน Roller Klin คือการเผาแบบแนวนอน จึงทำให้กระเบื้องแต่ละแผ่นได้รับความร้อนทั่วถึงทุกมุมองศาในระดับที่เท่ากัน จึงทำให้กระเบื้องเกิดการคงรูปพร้อมกัน จึงทำให้มีขนาดที่ได้มาตรฐานเท่ากันทุกแผ่น ซึ่งแตกต่างจากการเผาแบบเตาอุโมงค์\nน้ำหนัก\n4 กก.\nวัสดุ\nเซรามิค\nการดูแลรักษา\n- สีของผลิตภัณฑ์ในภาพอาจแตกต่างจากสีของผลิตภัณฑ์จริง เนื่องจากการแสดงผลหน้าจอที่แตกต่างกัน ควรพิจารณาสีของผลิตภัณฑ์จริงที่ร้านค้าก่อนการสั่งซื้อ\n- สภาพของผลิตภัณฑ์อาจมีการเปลี่ยนแปลงหรือเกิดคราบดำ ขึ้นอยู่กับสภาพแวดล้อมและการใช้งาน']

# df

# %%
df
# Out:
#                                                 image  \
# 0   https://www.scghome.com/_next/image?url=https%...
# 1   https://www.scghome.com/_next/image?url=https%...
# 2   https://www.scghome.com/_next/image?url=https%...
# 3   https://www.scghome.com/_next/image?url=https%...
# 4   https://www.scghome.com/_next/image?url=https%...
# 5   https://www.scghome.com/_next/image?url=https%...
# 6   https://www.scghome.com/_next/image?url=https%...
# 7   https://www.scghome.com/_next/image?url=https%...
# 8   https://www.scghome.com/_next/image?url=https%...
# 9   https://www.scghome.com/_next/image?url=https%...
# 10  https://www.scghome.com/_next/image?url=https%...
# 11  https://www.scghome.com/_next/image?url=https%...
# 12  https://www.scghome.com/_next/image?url=https%...
# 13  https://www.scghome.com/_next/image?url=https%...
# 14  https://www.scghome.com/_next/image?url=https%...
# 15  https://www.scghome.com/_next/image?url=https%...
# ...
